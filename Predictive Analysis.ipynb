# %% [markdown]
# Task 2
# # Predictive Analytics

# %% [markdown]
# The given Dataset is loaded into a dataframe using pandas library.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
excel_worksheet='ANZ synthesised transaction dataset.xlsx'

# %%
sheet1=pd.read_excel('ANZ synthesised transaction dataset.xlsx')

# %%
sheet1.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name   ...     age merchant_suburb merchant_state  \
# ...

# %%
sheet1.describe()
# Out:
#        card_present_flag  merchant_code        balance           age  \
# count        7717.000000          883.0   12043.000000  12043.000000
# mean            0.802644            0.0   14704.195553     30.582330
# std             0.398029            0.0   31503.722652     10.046343
# min             0.000000            0.0       0.240000     18.000000
# 25%             1.000000            0.0    3158.585000     22.000000
# 50%             1.000000            0.0    6432.010000     28.000000
# 75%             1.000000            0.0   12465.945000     38.000000
# max             1.000000            0.0  267128.520000     78.000000
#
#              amount
# count  12043.000000
# mean     187.933588
# std      592.599934
# min        0.100000
# 25%       16.000000
# 50%       29.000000
# 75%       53.655000
# max     8835.980000

# %% [markdown]
# The Dataset contains columns with missing values.The columns with missing values are dropped and new dataset is loaded referred as 'datasheet'.

# %%
datasheet=sheet1.dropna(axis=1)
datasheet
# Out:
#            status         account currency       long_lat txn_description  \
# 0      authorized  ACC-1598451071      AUD  153.41 -27.95             POS
# 1      authorized  ACC-1598451071      AUD  153.41 -27.95       SALES-POS
# 2      authorized  ACC-1222300524      AUD  151.23 -33.94             POS
# 3      authorized  ACC-1037050564      AUD  153.10 -27.66       SALES-POS
# 4      authorized  ACC-1598451071      AUD  153.41 -27.95       SALES-POS
# 5          posted  ACC-1608363396      AUD  151.22 -33.87         PAYMENT
# 6      authorized  ACC-2776252858      AUD  144.95 -37.76       SALES-POS
# 7      authorized  ACC-2776252858      AUD  144.95 -37.76             POS
# 8      authorized   ACC-182446574      AUD  116.06 -32.00             POS
# 9          posted   ACC-602667573      AUD  151.23 -33.96      INTER BANK
# 10         posted  ACC-2171593283      AUD  146.94 -36.04         PAYMENT
# 11         posted  ACC-2776252858      AUD  144.95 -37.76         PAYMENT
# ...

# %%
datasheet.describe()
# Out:
#              balance           age        amount
# count   12043.000000  12043.000000  12043.000000
# mean    14704.195553     30.582330    187.933588
# std     31503.722652     10.046343    592.599934
# min         0.240000     18.000000      0.100000
# 25%      3158.585000     22.000000     16.000000
# 50%      6432.010000     28.000000     29.000000
# 75%     12465.945000     38.000000     53.655000
# max    267128.520000     78.000000   8835.980000

# %% [markdown]
# A copy of 'datasheet' is made to perform various operations upon. Furthermore, the transaction column is filtered and salary transactions are loaded into a new dataframe called 'salary_transactions'.

# %%
datasheet_copy=datasheet.copy()

# %%
salary_transactions= datasheet_copy[datasheet_copy.txn_description =='PAY/SALARY']

# %%
salary_transactions
# Out:
#        status         account currency       long_lat txn_description  \
# 50     posted   ACC-588564840      AUD  151.27 -33.76      PAY/SALARY
# 61     posted  ACC-1650504218      AUD  145.01 -37.93      PAY/SALARY
# 64     posted  ACC-3326339947      AUD  151.18 -33.80      PAY/SALARY
# 68     posted  ACC-3541460373      AUD  145.00 -37.83      PAY/SALARY
# 70     posted  ACC-2776252858      AUD  144.95 -37.76      PAY/SALARY
# 72     posted  ACC-1598451071      AUD  153.41 -27.95      PAY/SALARY
# 90     posted  ACC-3485804958      AUD  138.52 -35.01      PAY/SALARY
# 92     posted  ACC-1973887809      AUD  115.78 -31.90      PAY/SALARY
# 93     posted  ACC-4059612845      AUD  130.98 -12.49      PAY/SALARY
# 97     posted   ACC-819621312      AUD  145.04 -37.85      PAY/SALARY
# 98     posted  ACC-2920611728      AUD  144.96 -37.76      PAY/SALARY
# 100    posted  ACC-1799207998      AUD  150.68 -33.79      PAY/SALARY
# ...

# %% [markdown]
# The redundant transactions are removed so that our dataframe contains only one salary transaction for each customer.

# %%
salary_transactions.drop_duplicates(subset=['amount'])
# Out:
#       status         account currency       long_lat txn_description  \
# 50    posted   ACC-588564840      AUD  151.27 -33.76      PAY/SALARY
# 61    posted  ACC-1650504218      AUD  145.01 -37.93      PAY/SALARY
# 64    posted  ACC-3326339947      AUD  151.18 -33.80      PAY/SALARY
# 68    posted  ACC-3541460373      AUD  145.00 -37.83      PAY/SALARY
# 70    posted  ACC-2776252858      AUD  144.95 -37.76      PAY/SALARY
# 72    posted  ACC-1598451071      AUD  153.41 -27.95      PAY/SALARY
# 90    posted  ACC-3485804958      AUD  138.52 -35.01      PAY/SALARY
# 92    posted  ACC-1973887809      AUD  115.78 -31.90      PAY/SALARY
# 93    posted  ACC-4059612845      AUD  130.98 -12.49      PAY/SALARY
# 97    posted   ACC-819621312      AUD  145.04 -37.85      PAY/SALARY
# 98    posted  ACC-2920611728      AUD  144.96 -37.76      PAY/SALARY
# 100   posted  ACC-1799207998      AUD  150.68 -33.79      PAY/SALARY
# 101   posted  ACC-1349834573      AUD  145.17 -37.84      PAY/SALARY
# ...

# %% [markdown]
# A new dataframe called 'Annual_salary_list' is made in which several important details & insights are loaded as columns.

# %%
Annual_salary_list =pd.DataFrame(columns=['customer_id','age','weekly_salary','annual_salary','mean_purchase_amt_for_three_months','mean_yearly_purchase_amt'])

# %%
Annual_salary_list.customer_id= salary_transactions.drop_duplicates(subset=['amount']).customer_id

# %%
Annual_salary_list.age= salary_transactions.drop_duplicates(subset=['amount']).age

# %%
Annual_salary_list.weekly_salary= salary_transactions.drop_duplicates(subset=['amount']).amount

# %%
Annual_salary_list.annual_salary= Annual_salary_list.weekly_salary*52

# %%
Annual_salary_list.set_index('customer_id',inplace=True)

# %% [markdown]
# The original dataframe is filtered to find purchase transactions and are loaded in a new dataframe called 'purchase_transactions'.
# Further the mean purchase amount for given 3 months by every customer is calculated.

# %%
purchase_transactions= datasheet_copy[(datasheet_copy.txn_description== 'POS') | (datasheet_copy.txn_description== 'SALES-POS')]
purchase_transactions
# Out:
#            status         account currency       long_lat txn_description  \
# 0      authorized  ACC-1598451071      AUD  153.41 -27.95             POS
# 1      authorized  ACC-1598451071      AUD  153.41 -27.95       SALES-POS
# 2      authorized  ACC-1222300524      AUD  151.23 -33.94             POS
# 3      authorized  ACC-1037050564      AUD  153.10 -27.66       SALES-POS
# 4      authorized  ACC-1598451071      AUD  153.41 -27.95       SALES-POS
# 6      authorized  ACC-2776252858      AUD  144.95 -37.76       SALES-POS
# 7      authorized  ACC-2776252858      AUD  144.95 -37.76             POS
# 8      authorized   ACC-182446574      AUD  116.06 -32.00             POS
# 12     authorized   ACC-182446574      AUD  116.06 -32.00       SALES-POS
# 15     authorized  ACC-1903037542      AUD  153.05 -27.61             POS
# 19     authorized  ACC-4258502723      AUD  145.45 -37.74             POS
# 20     authorized  ACC-1598451071      AUD  153.41 -27.95             POS
# ...

# %%
x=purchase_transactions.groupby('customer_id').amount.mean()
x
# Out:
# customer_id
# CUS-1005756958     37.726250
# CUS-1117979751     76.458077
# CUS-1140341822     67.531385
# CUS-1147642491     51.128289
# CUS-1196156254     30.310491
# CUS-1220154422     65.928958
# CUS-1233833708     36.663200
# CUS-1271030853    149.318154
# CUS-127297539      29.717792
# CUS-134193016      34.779630
# CUS-134833760      39.179302
# CUS-1388323263     32.651698
# CUS-1433879684     36.298182
# CUS-1462656821     50.242969
# CUS-1478398256     41.067541
# CUS-1499065773     72.603429
# CUS-1604596597     30.659341
# CUS-1609060617     84.430600
# CUS-1614226872     31.114864
# CUS-1617121891     75.156456
# CUS-164374203      43.258614
# CUS-1646183815     23.736667
# CUS-1646621553     51.412597
# CUS-1654129794     37.786780
# CUS-1669695324     28.805029
# CUS-1739931018     22.320000
# CUS-1790886359     48.145085
# CUS-1816693151     65.648571
# CUS-1842679196     23.158235
# CUS-1892177589     33.759841
#                      ...
# ...

# %% [markdown]
# Here, the goal is to find a customer attribute based on their spending habits. So, the mean spending for 3 months is found and it is multiplied by 4 to make a new attribute called 'mean_yearly_purchase_amt' and it is added as a column to the 'Annual_salary_list' dataframe.

# %%
Annual_salary_list.mean_purchase_amt_for_three_months=x
Annual_salary_list.mean_yearly_purchase_amt=x*4
Annual_salary_list
# Out:
#                 age  weekly_salary  annual_salary  \
# customer_id
# CUS-1462656821   23        3903.95      203005.40
# CUS-2500783281   23        1626.48       84576.96
# CUS-326006476    22         983.36       51134.72
# CUS-1433879684   24        1408.08       73220.16
# CUS-4123612273   43        1068.04       55538.08
# CUS-2487424745   26        1013.67       52710.84
# CUS-1196156254   34        3903.73      202993.96
# CUS-1646621553   26        1098.91       57143.32
# CUS-495599312    38        2647.38      137663.76
# CUS-1271030853   30        1158.15       60223.80
# CUS-1388323263   69        1043.12       54242.24
# CUS-164374203    20        1395.49       72565.48
# CUS-1790886359   39        3071.14      159699.28
# CUS-2630892467   26         920.71       47876.92
# CUS-1646183815   78         782.42       40685.84
# CUS-2283904812   22        2218.73      115373.96
# CUS-860700529    30        1808.62       94048.24
# ...

# %% [markdown]
# The Correlation between customer attribute 'age' and 'annual_salary' is plotted using a scatter plot.

# %%
plt.scatter(Annual_salary_list.age,Annual_salary_list.annual_salary,c='r')
plt.show()

# %% [markdown]
# Furthermore, a regression model is built to predict annual salaries based on previous observations of age and salaries.

# %%
import numpy as np
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\Saurabh\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
reg= linear_model.LinearRegression()

# %% [markdown]
# The 'age' column and 'annual_salary' column is split into train and test sets and fitted using the regression function.

# %%
x_train,x_test,y_train,y_test = train_test_split(Annual_salary_list[['age']],Annual_salary_list.annual_salary,test_size=0.2,random_state=4)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# array([-635.99963303])

# %%
reg.intercept_
# Out:
# 138381.13944036697

# %% [markdown]
# The salaries of test set observations are predicted using regression model and can be compared with actual salaries which are given below.

# %%
predicted_salaries=reg.predict(x_test)
predicted_salaries
# Out:
# array([ 114849.15301835,   94497.16476147,  119301.15044954,
#         119301.15044954,  114213.15338532,  125661.14677982,
#         120573.1497156 ,  123117.14824771,  119937.15008257,
#         111033.15522018,  116121.1522844 ,  124389.14751376,
#         112941.15411927,  125025.14714679,  121845.14898165,
#         125025.14714679,   88773.16806422,  122481.14861468,
#         124389.14751376,  126297.14641284])

# %%
y_test
# Out:
# customer_id
# CUS-3201519139     47671.00
# CUS-1388323263     54242.24
# CUS-497688347     255366.80
# CUS-860700529      94048.24
# CUS-2142601169     52110.76
# CUS-127297539      59217.08
# CUS-4023861240    132011.36
# CUS-423725039     193053.12
# CUS-261674136     229075.60
# CUS-3255104878     34550.36
# CUS-2650223890     44873.40
# CUS-326006476      51134.72
# CUS-1816693151    459470.96
# CUS-134193016     105231.36
# CUS-2630892467     47876.92
# CUS-537508723     133791.32
# CUS-1646183815     40685.84
# CUS-1669695324     63717.16
# CUS-1617121891    173096.04
# CUS-883482547     206827.92
# Name: annual_salary, dtype: float64

# %% [markdown]
# Now that the regression model is built, its accuracy is checked using many factors,one of which is the mean squared error method in which the mean of squares of error(predicted value-actual value) is calculated. If the value is found to be high, the model is said to be poorly performing.
#
# In case of our regression, the mean squared error value is very which suggest that our model is not accurately predicting values or the data fed to model shows no correlation. Hence, it is clear that this model cannot be used to predict real world values.

# %%
# mean squared error to test accuracy of regression model

np.mean((predicted_salaries-y_test)**2)
# Out:
# 10371380486.808159

# %% [markdown]
# Furthermore, another regression model is built to predict salary based on derived customer attribute which is the mean spending over an year(mean spending over 3 months * 4)
#
# A scatter plot for the same values is plotted below.

# %%
plt.scatter(Annual_salary_list.mean_yearly_purchase_amt,Annual_salary_list.annual_salary,c='b')
plt.show()

# %% [markdown]
# The 'mean_yearly_purchase_amt' column and 'annual_salary' column is split into train and test sets and fitted using the regression function.

# %%
x_train,x_test,y_train,y_test = train_test_split(Annual_salary_list[['mean_yearly_purchase_amt']],Annual_salary_list.annual_salary,test_size=0.2,random_state=4)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# array([-33.18762891])

# %%
reg.intercept_
# Out:
# 124792.66518983083

# %% [markdown]
# The salaries of test set observations are predicted using regression model and can be compared with actual salaries which are given below.

# %%
predicted_salaries=reg.predict(x_test)
predicted_salaries
# Out:
# array([ 106043.08447413,  120458.13542821,  116292.51467175,
#         120936.99734875,  120134.00709369,  120847.61295004,
#         118024.9400099 ,  121322.15370894,  119555.89510926,
#         112180.54441345,  112771.81560528,  119477.50048105,
#         116077.7834805 ,  120175.65142212,  120667.11103948,
#         120621.89289509,  121641.61044984,  120968.78274959,
#         114815.60694116,  120692.67657629])

# %%
y_test
# Out:
# customer_id
# CUS-3201519139     47671.00
# CUS-1388323263     54242.24
# CUS-497688347     255366.80
# CUS-860700529      94048.24
# CUS-2142601169     52110.76
# CUS-127297539      59217.08
# CUS-4023861240    132011.36
# CUS-423725039     193053.12
# CUS-261674136     229075.60
# CUS-3255104878     34550.36
# CUS-2650223890     44873.40
# CUS-326006476      51134.72
# CUS-1816693151    459470.96
# CUS-134193016     105231.36
# CUS-2630892467     47876.92
# CUS-537508723     133791.32
# CUS-1646183815     40685.84
# CUS-1669695324     63717.16
# CUS-1617121891    173096.04
# CUS-883482547     206827.92
# Name: annual_salary, dtype: float64

# %% [markdown]
# In case of this regression model too, the value of mean squared error is found to be very high and hence it is concluded that this model is poorly performing and the data on which model is built shows no or very less correlation.
#
# Hence, both the models cannot be used for reporting purposes.

# %%
# mean squared error to test accuracy of regression model

np.mean((predicted_salaries-y_test)**2)
# Out:
# 10659320525.474178
